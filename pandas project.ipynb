# %%
# Pandas is used for data processing and analysis
# Used to create 2-dimensional tabular data structure with labled axis
import pandas as pd                         # importing Pandas library under the alias "pd"
dataframe = pd.read_csv("Name/path of file")       # read csv file
dataframe = pd.read_excel("Name/path of file")     # read excel file
dataframe.to_csv("file name")                      # converts file to csv format
dataframe.shape                                    # gives shape, i.e number of rows and columns in dataframe
dataframe.info                                     # give information about dataframe
dataframe.value_counts("column name")              # gives the count of different values in column
dataframe.mean()                                   # gives mean of each column
dataframe.describe                                 # gives all statistical measures of dataframe
dataframe.drop(index=0,axis=0)                     # to remove row axis should be 0 and for column it should be 1
dataframe.drop(columns="column name",axis=1)       # remove column

# %%
import pandas as pd
import numpy as np
adult_df = pd.read_csv("adult.csv")
adult_df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
adult_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  country         32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult_df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
adult_df.value_counts("education")
# Out:
# education
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: count, dtype: int64

# %%
adult_df.age.mean()
# Out:
# 38.58164675532078

# %%
adult_df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
adult_df.drop(columns = "race",axis = 1)
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship      sex  \
# 0            Never-married        Adm-clerical   Not-in-family     Male
# ...

# %%
df1 = adult_df.groupby("country")
df1.first()
# Out:
#                              age          workclass  fnlwgt      education  \
# country
#  ?                            40            Private  121772      Assoc-voc
#  Cambodia                     42   Self-emp-not-inc  303044        HS-grad
#  Canada                       56   Self-emp-not-inc  335605        HS-grad
#  China                        51   Self-emp-not-inc  160724      Bachelors
#  Columbia                     75            Private  314209      Assoc-voc
#  Cuba                         28            Private  338409      Bachelors
#  Dominican-Republic           23            Private  204653        HS-grad
#  Ecuador                      50            Private  193884        7th-8th
#  El-Salvador                  23            Private  403107        5th-6th
#  England                      48            Private  171095     Assoc-acdm
#  France                       58            Private  180980   Some-college
# ...

# %%
random_col = np.random.randint(100, size=len(adult_df))
adult_df.insert(3, 'random', random_col)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32380\1079525917.py in ?()
#       1 random_col = np.random.randint(100, size=len(adult_df))
# ----> 2 adult_df.insert(3, 'random', random_col)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    4768                 "'self.flags.allows_duplicate_labels' is False."
#    4769             )
#    4770         if not allow_duplicates and column in self.columns:
#    4771             # Should this be a different kind of error??
# -> 4772             raise ValueError(f"cannot insert {column}, already exists")
#    4773         if not isinstance(loc, int):
#    4774             raise TypeError("loc must be int")
#    4775
#
# ValueError: cannot insert random, already exists
